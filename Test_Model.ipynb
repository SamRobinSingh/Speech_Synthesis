# %%
from kokoro import KPipeline
from IPython.display import display, Audio
import soundfile as sf

# %%
pip install unicodedata
# Out:
# Collecting mojimoji
#   Downloading mojimoji-0.0.13-cp311-cp311-win_amd64.whl.metadata (3.6 kB)
# Downloading mojimoji-0.0.13-cp311-cp311-win_amd64.whl (43 kB)
# Installing collected packages: mojimoji
# Successfully installed mojimoji-0.0.13
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pipeline = KPipeline(lang_code='a')

# %%
text = '''
The sky above the port was the color of television, tuned to a dead channel.
'''

# %%
generator = pipeline(
    text, voice='af_heart', # <= change voice here
    speed=1, split_pattern=r'\n+'
)

# %%
for i, (gs, ps, audio) in enumerate(generator):
    print(i)  # i => index
    print(gs) # gs => graphemes/text
    print(ps) # ps => phonemes
    display(Audio(data=audio, rate=24000, autoplay=i==0))
    sf.write(f'{i}.wav', audio, 24000)
# Out:
# 0
# The sky above the port was the color of television, tuned to a dead channel.
# ðə skˈI əbˈʌv ðə pˈɔɹt wʌz ðə kˈʌləɹ ʌv tˈɛləvˌɪʒən, tˈund tə ɐ dˈɛd ʧˈænᵊl.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
